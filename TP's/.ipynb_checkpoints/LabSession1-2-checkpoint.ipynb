# %% [markdown]
# <div id="image">
# <img src="https://www.imt-atlantique.fr/sites/default/files/logo_mt_0_0.png" WIDTH=280 HEIGHT=280>
# </div>
# <div id="subject">
# <CENTER>
# </br>
# <font size="5"></br> UE Deep Learning: Lab sessions 1 and 2</font></br></div>
# </CENTER>
# <CENTER>
# <font size="3"></br>15th and 19th of Octobre 2018</font></br></div>
# </CENTER>
# <CENTER>
# <span style="color:blue">pierre.tandeo@imt-atlantique.fr</span>
# </CENTER>
# <CENTER>
# <span style="color:blue">pierre-henri.conze@imt-atlantique.fr</span>
# </CENTER>
# <CENTER>
# <span style="color:blue">lucas.drumetz@imt-atlantique.fr</span>
# </CENTER>
# </div>

# %% [markdown]
# The aim of this practice is to explain $Y$ (output variable) as a function of $X$ (input variable) using neural networks. Here, $X$ are continuous and $Y$ can be continuous (*regression*) or discrete (*classification*). These 2 aspects are treated in the deep learning framework. Both linear and nonlinear cases will be covered in this lab session.
#
# We use the Keras Python library to implement deep learning architectures. This interface has the following characteristics:
# - it is developped for both *Tensorflow* and *Theano*
# - it can be applied to CPU or GPU without distinction
# - it can interact with classical machine learning libraries like *Scikit-learn*
#
# This lab session is an introduction. It gives you the general concepts of neural nets and helps you to implement them using a dedicated Python library. If you want to play with similar regression/classification examples in small dimensions, you can use http://playground.tensorflow.org/. For more details concerning Keras, please visit the documentation at https://keras.io/.

# %%
# Import libraries
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize']=(15,15)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Regression problems**
#
# Simple regression is a linear problem between continuous variables $X$ and $Y$. Here, we write the model $Y=2+0.5X$ and generate $Y$ using an additional Gaussian standard random noise.

# %%
# Generate data
n=1000
X=random.uniform(-10,10,n)
Y_true=2+0.5*X # true model
Y=Y_true+random.normal(0,1,n) # add noise to the truth
plot(X,Y,'b.')

# Plot noisy data and true model
plot(X,Y,'b.')
plot(X,Y_true,'r.')
xlabel('X')
ylabel('Y')
# Out:
# Text(0,0.5,'Y')

# %% [markdown]
# Here, the objective is to build a neural net to fit the linear relationships between $X$ and $Y$. We use the mean absolute error as loss function and the stochastic gradient descent (sgd) algorithm for the optimization procedure. Then, we fit the model on a training dataset (80%) and we evaluate the performance of the model on a test dataset (20%). Finally, we plot the estimated parameters corresponding to the weights for each neurone.

# %%
# Import deep learning library
from keras.models import Sequential
from keras.layers.core import Activation, Dense
from keras.optimizers import SGD, Adam

# Build our model
model_regress1 = Sequential()
 
# Declare the layers
layers = [Dense(units=1, input_dim=1), Activation('linear')]
 
# Add the layers to the model
for layer in layers:
    model_regress1.add(layer)

# Configure an optimizer used to minimize the loss function
sgd = SGD(lr=0.1, decay=.01)

# Compile our model
model_regress1.compile(loss='mean_absolute_error', optimizer=sgd)
 
# Fit the model
model_regress1.fit(X, Y, validation_split=0.2, epochs=100)

# Model summary and weights
model_regress1.get_weights() # model_regress1.layers[0].get_weights()
# Out:
# Train on 800 samples, validate on 200 samples
# Epoch 1/100
# 800/800 [==============================] - 0s 163us/step - loss: 1.4101 - val_loss: 0.9721
# Epoch 2/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.9089 - val_loss: 1.2128
# Epoch 3/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8660 - val_loss: 0.9207
# Epoch 4/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8286 - val_loss: 0.9230
# Epoch 5/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8444 - val_loss: 0.9187
# Epoch 6/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8403 - val_loss: 1.0123
# Epoch 7/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8374 - val_loss: 0.9268
# Epoch 8/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8347 - val_loss: 0.9250
# Epoch 9/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8253 - val_loss: 0.9190
# Epoch 10/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8256 - val_loss: 0.9215
# Epoch 11/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8237 - val_loss: 0.9215
# Epoch 12/100
# 800/800 [==============================] - 0s 53us/step - loss: 0.8139 - val_loss: 0.9351
# Epoch 13/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8257 - val_loss: 0.9300
# Epoch 14/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8143 - val_loss: 0.9187
# Epoch 15/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8190 - val_loss: 0.9202
# Epoch 16/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8156 - val_loss: 0.9191
# Epoch 17/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8128 - val_loss: 0.9183
# Epoch 18/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8137 - val_loss: 0.9203
# Epoch 19/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8173 - val_loss: 0.9182
# Epoch 20/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8196 - val_loss: 0.9185
# Epoch 21/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8172 - val_loss: 0.9184
# Epoch 22/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8173 - val_loss: 0.9185
# Epoch 23/100
# 800/800 [==============================] - 0s 53us/step - loss: 0.8155 - val_loss: 0.9274
# Epoch 24/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8179 - val_loss: 0.9191
# Epoch 25/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8161 - val_loss: 0.9187
# Epoch 26/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8180 - val_loss: 0.9186
# Epoch 27/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8135 - val_loss: 0.9185
# Epoch 28/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8157 - val_loss: 0.9193
# Epoch 29/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8129 - val_loss: 0.9183
# Epoch 30/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8124 - val_loss: 0.9223
# Epoch 31/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8139 - val_loss: 0.9196
# Epoch 32/100
# 800/800 [==============================] - 0s 53us/step - loss: 0.8134 - val_loss: 0.9199
# Epoch 33/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8128 - val_loss: 0.9186
# Epoch 34/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8142 - val_loss: 0.9204
# Epoch 35/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8137 - val_loss: 0.9186
# Epoch 36/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8153 - val_loss: 0.9205
# Epoch 37/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8133 - val_loss: 0.9184
# Epoch 38/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8100 - val_loss: 0.9202
# Epoch 39/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8110 - val_loss: 0.9207
# Epoch 40/100
# 800/800 [==============================] - 0s 52us/step - loss: 0.8124 - val_loss: 0.9203
# Epoch 41/100
# 800/800 [==============================] - 0s 53us/step - loss: 0.8123 - val_loss: 0.9192
# Epoch 42/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8137 - val_loss: 0.9191
# Epoch 43/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8118 - val_loss: 0.9186
# Epoch 44/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8102 - val_loss: 0.9186
# Epoch 45/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8115 - val_loss: 0.9188
# Epoch 46/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8094 - val_loss: 0.9270
# Epoch 47/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8144 - val_loss: 0.9207
# Epoch 48/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8137 - val_loss: 0.9200
# Epoch 49/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8129 - val_loss: 0.9201
# Epoch 50/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8094 - val_loss: 0.9188
# Epoch 51/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8135 - val_loss: 0.9187
# Epoch 52/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8102 - val_loss: 0.9240
# Epoch 53/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8099 - val_loss: 0.9184
# Epoch 54/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8108 - val_loss: 0.9187
# Epoch 55/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8125 - val_loss: 0.9199
# Epoch 56/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8113 - val_loss: 0.9218
# Epoch 57/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8110 - val_loss: 0.9214
# Epoch 58/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8123 - val_loss: 0.9194
# Epoch 59/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8119 - val_loss: 0.9213
# Epoch 60/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8108 - val_loss: 0.9201
# Epoch 61/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8105 - val_loss: 0.9189
# Epoch 62/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8114 - val_loss: 0.9186
# Epoch 63/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8124 - val_loss: 0.9187
# Epoch 64/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8119 - val_loss: 0.9186
# Epoch 65/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8077 - val_loss: 0.9241
# Epoch 66/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8132 - val_loss: 0.9191
# Epoch 67/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8118 - val_loss: 0.9186
# Epoch 68/100
# 800/800 [==============================] - 0s 50us/step - loss: 0.8099 - val_loss: 0.9184
# Epoch 69/100
# 800/800 [==============================] - 0s 51us/step - loss: 0.8110 - val_loss: 0.9235
# Epoch 70/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8107 - val_loss: 0.9188
# Epoch 71/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8113 - val_loss: 0.9201
# Epoch 72/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8118 - val_loss: 0.9188
# Epoch 73/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8109 - val_loss: 0.9194
# Epoch 74/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8121 - val_loss: 0.9231
# Epoch 75/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8117 - val_loss: 0.9207
# Epoch 76/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8109 - val_loss: 0.9189
# Epoch 77/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8117 - val_loss: 0.9188
# Epoch 78/100
# 800/800 [==============================] - 0s 53us/step - loss: 0.8105 - val_loss: 0.9200
# Epoch 79/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8107 - val_loss: 0.9207
# Epoch 80/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8109 - val_loss: 0.9186
# Epoch 81/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8118 - val_loss: 0.9199
# Epoch 82/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8108 - val_loss: 0.9189
# Epoch 83/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8102 - val_loss: 0.9187
# Epoch 84/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8118 - val_loss: 0.9186
# Epoch 85/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8096 - val_loss: 0.9185
# Epoch 86/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8092 - val_loss: 0.9208
# Epoch 87/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8108 - val_loss: 0.9188
# Epoch 88/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8110 - val_loss: 0.9188
# Epoch 89/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8101 - val_loss: 0.9192
# Epoch 90/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8099 - val_loss: 0.9188
# Epoch 91/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8114 - val_loss: 0.9194
# Epoch 92/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8121 - val_loss: 0.9190
# Epoch 93/100
# 800/800 [==============================] - 0s 53us/step - loss: 0.8097 - val_loss: 0.9186
# Epoch 94/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8110 - val_loss: 0.9189
# Epoch 95/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8126 - val_loss: 0.9189
# Epoch 96/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8123 - val_loss: 0.9190
# Epoch 97/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8103 - val_loss: 0.9209
# Epoch 98/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8107 - val_loss: 0.9189
# Epoch 99/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8109 - val_loss: 0.9193
# Epoch 100/100
# 800/800 [==============================] - 0s 52us/step - loss: 0.8109 - val_loss: 0.9189
# [array([[0.5087592]], dtype=float32), array([1.9551094], dtype=float32)]

# %% [markdown]
# We can see that the estimated parameters are closed to the true ones ($2$ for the intercept and $0.5$ for the slope). Below, we plot the true model (red) and the estimated one (green).

# %%
# Make prediction using the model
Y_hat = model_regress1.predict(X)

# Plot noisy data, true model and prediction
plot(X,Y,'b.')
plot(X,Y_true,'r.',linewidth=2)
plot(X,Y_hat,'g.',linewidth=2)
xlabel('X')
ylabel('Y')
# Out:
# Text(0,0.5,'Y')

# %% [markdown]
# Now, let us consider a model where for a same input variable $X$, we associate 2 output variables $Y_0$ and $Y_1$ defined by $Y_0=2+0.5X$ and $Y_1=-2-0.5X$. As previously, we use Gaussian additive noises to generate $Y_0$ and $Y_1$.

# %%
# Generate data
n=1000
X=random.uniform(-10,10,n)
Y0_true=2+0.5*X # true model
Y0=Y0_true+random.normal(0,1,n) # add noise
Y1_true=-2-0.5*X # true model
Y1=Y1_true+random.normal(0,1,n) # add noise
Y_true=vstack([Y0_true,Y1_true]).T
Y=vstack([Y0,Y1]).T

# Plot noisy data and true model
plot(X,Y,'b.')
plot(X,Y_true,'r.')
xlabel('X')
ylabel('Y')
# Out:
# Text(0,0.5,'Y')

# %% [markdown]
# Here we modify the hidden layer to account for the 2 output variables $Y_0$ et $Y_1$.

# %%
# Build our model
model_regress2 = Sequential()

# Declare the layers
layers = [Dense(units=2,input_dim=1), Activation('linear')]
cont = 0
# Add the layers to the model
for layer in layers:
    cont += 1
    model_regress2.add(layer)
    print("contador",cont)
# Configure an optimizer used to minimize the loss function
sgd = SGD(lr=0.1, decay=.01)

# Compile our model
model_regress2.compile(loss='mean_absolute_error', optimizer=sgd)
 
# Fit the model
model_regress2.fit(X, Y, validation_split=0.2, epochs=100)
                   
# Model weights
model_regress2.get_weights()
# Out:
# contador 1
# contador 2
# Train on 800 samples, validate on 200 samples
# Epoch 1/100
# 800/800 [==============================] - 0s 195us/step - loss: 2.0586 - val_loss: 1.3091
# Epoch 2/100
# 800/800 [==============================] - 0s 55us/step - loss: 1.1110 - val_loss: 0.9723
# Epoch 3/100
# 800/800 [==============================] - 0s 53us/step - loss: 0.9157 - val_loss: 0.8442
# Epoch 4/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8555 - val_loss: 0.8192
# Epoch 5/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8377 - val_loss: 0.8085
# Epoch 6/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8299 - val_loss: 0.7961
# Epoch 7/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8255 - val_loss: 0.7935
# Epoch 8/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8203 - val_loss: 0.7969
# Epoch 9/100
# 800/800 [==============================] - 0s 53us/step - loss: 0.8226 - val_loss: 0.7900
# Epoch 10/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8201 - val_loss: 0.7829
# Epoch 11/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8199 - val_loss: 0.7965
# Epoch 12/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8211 - val_loss: 0.7965
# Epoch 13/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8175 - val_loss: 0.7831
# Epoch 14/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8203 - val_loss: 0.7847
# Epoch 15/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8199 - val_loss: 0.7893
# Epoch 16/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8189 - val_loss: 0.7839
# Epoch 17/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8165 - val_loss: 0.7944
# Epoch 18/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8186 - val_loss: 0.7828
# Epoch 19/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8183 - val_loss: 0.7844
# Epoch 20/100
# 800/800 [==============================] - 0s 63us/step - loss: 0.8193 - val_loss: 0.7878
# Epoch 21/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8189 - val_loss: 0.7821
# Epoch 22/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8167 - val_loss: 0.7862
# Epoch 23/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8180 - val_loss: 0.7859
# Epoch 24/100
# 800/800 [==============================] - 0s 63us/step - loss: 0.8184 - val_loss: 0.7850
# Epoch 25/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8181 - val_loss: 0.7851
# Epoch 26/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8181 - val_loss: 0.7858
# Epoch 27/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8172 - val_loss: 0.7850
# Epoch 28/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8165 - val_loss: 0.7843
# Epoch 29/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8181 - val_loss: 0.7829
# Epoch 30/100
# 800/800 [==============================] - 0s 63us/step - loss: 0.8181 - val_loss: 0.7829
# Epoch 31/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8169 - val_loss: 0.7861
# Epoch 32/100
# 800/800 [==============================] - 0s 62us/step - loss: 0.8152 - val_loss: 0.7845
# Epoch 33/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8172 - val_loss: 0.7819
# Epoch 34/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8175 - val_loss: 0.7840
# Epoch 35/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8166 - val_loss: 0.7903
# Epoch 36/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8185 - val_loss: 0.7834
# Epoch 37/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8163 - val_loss: 0.7869
# Epoch 38/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8173 - val_loss: 0.7847
# Epoch 39/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8162 - val_loss: 0.7849
# Epoch 40/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8168 - val_loss: 0.7843
# Epoch 41/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8160 - val_loss: 0.7858
# Epoch 42/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8162 - val_loss: 0.7866
# Epoch 43/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8160 - val_loss: 0.7834
# Epoch 44/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8168 - val_loss: 0.7849
# Epoch 45/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8167 - val_loss: 0.7839
# Epoch 46/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8167 - val_loss: 0.7831
# Epoch 47/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8173 - val_loss: 0.7843
# Epoch 48/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8165 - val_loss: 0.7834
# Epoch 49/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8168 - val_loss: 0.7859
# Epoch 50/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8161 - val_loss: 0.7837
# Epoch 51/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8170 - val_loss: 0.7828
# Epoch 52/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8172 - val_loss: 0.7834
# Epoch 53/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8166 - val_loss: 0.7844
# Epoch 54/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8159 - val_loss: 0.7867
# Epoch 55/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8160 - val_loss: 0.7828
# Epoch 56/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8163 - val_loss: 0.7822
# Epoch 57/100
# 800/800 [==============================] - 0s 63us/step - loss: 0.8160 - val_loss: 0.7857
# Epoch 58/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8161 - val_loss: 0.7829
# Epoch 59/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8159 - val_loss: 0.7836
# Epoch 60/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8161 - val_loss: 0.7852
# Epoch 61/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8158 - val_loss: 0.7844
# Epoch 62/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8163 - val_loss: 0.7851
# Epoch 63/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8167 - val_loss: 0.7839
# Epoch 64/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8163 - val_loss: 0.7827
# Epoch 65/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8164 - val_loss: 0.7848
# Epoch 66/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8163 - val_loss: 0.7837
# Epoch 67/100
# 800/800 [==============================] - 0s 54us/step - loss: 0.8165 - val_loss: 0.7855
# Epoch 68/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8158 - val_loss: 0.7840
# Epoch 69/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8167 - val_loss: 0.7842
# Epoch 70/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8161 - val_loss: 0.7853
# Epoch 71/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8158 - val_loss: 0.7839
# Epoch 72/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8158 - val_loss: 0.7841
# Epoch 73/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8153 - val_loss: 0.7833
# Epoch 74/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8160 - val_loss: 0.7833
# Epoch 75/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8160 - val_loss: 0.7837
# Epoch 76/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8158 - val_loss: 0.7837
# Epoch 77/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8160 - val_loss: 0.7830
# Epoch 78/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8154 - val_loss: 0.7833
# Epoch 79/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8166 - val_loss: 0.7843
# Epoch 80/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8159 - val_loss: 0.7834
# Epoch 81/100
# 800/800 [==============================] - 0s 55us/step - loss: 0.8159 - val_loss: 0.7834
# Epoch 82/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8142 - val_loss: 0.7891
# Epoch 83/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8160 - val_loss: 0.7845
# Epoch 84/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8159 - val_loss: 0.7831
# Epoch 85/100
# 800/800 [==============================] - 0s 62us/step - loss: 0.8155 - val_loss: 0.7842
# Epoch 86/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8158 - val_loss: 0.7828
# Epoch 87/100
# 800/800 [==============================] - 0s 62us/step - loss: 0.8161 - val_loss: 0.7832
# Epoch 88/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8158 - val_loss: 0.7833
# Epoch 89/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8160 - val_loss: 0.7843
# Epoch 90/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8157 - val_loss: 0.7829
# Epoch 91/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8162 - val_loss: 0.7826
# Epoch 92/100
# 800/800 [==============================] - 0s 57us/step - loss: 0.8158 - val_loss: 0.7847
# Epoch 93/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8155 - val_loss: 0.7844
# Epoch 94/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8155 - val_loss: 0.7844
# Epoch 95/100
# 800/800 [==============================] - 0s 56us/step - loss: 0.8159 - val_loss: 0.7837
# Epoch 96/100
# 800/800 [==============================] - 0s 62us/step - loss: 0.8154 - val_loss: 0.7839
# Epoch 97/100
# 800/800 [==============================] - 0s 61us/step - loss: 0.8153 - val_loss: 0.7845
# Epoch 98/100
# 800/800 [==============================] - 0s 59us/step - loss: 0.8158 - val_loss: 0.7843
# Epoch 99/100
# 800/800 [==============================] - 0s 60us/step - loss: 0.8155 - val_loss: 0.7854
# Epoch 100/100
# 800/800 [==============================] - 0s 58us/step - loss: 0.8158 - val_loss: 0.7852
# [array([[ 0.5090172 , -0.51497984]], dtype=float32),
#  array([ 2.0153668, -1.9752349], dtype=float32)]

# %% [markdown]
# We then compare the fitted (green) and true (red) models.

# %%
# Make prediction using the model
Y_hat = model_regress2.predict(X)

# Plot train, test and hat
plot(X,Y,'b.')
plot(X,Y_true,'.r',linewidth=2)
plot(X,Y_hat,'.g',linewidth=2)
xlabel('X')
ylabel('Y')

# %% [markdown]
# **Classification problems**
#
# In a classification problem, $Y$ is a discrete variable with various classes. Here, $Y$ is binary and takes its values between $0$ and $1$. We write the model as $Y=f\left(2+0.5 X\right)$ with $f$ the logistic transfer function (sigmoid). As previously we generate $Y$ adding Gaussian perturbations.

# %%
# Generate data
n=1000
X=random.uniform(-14,8,n)
Y_true=1/(1+exp(-(2+0.5*X))) # true model
Y_noise=1/(1+exp(-(2+0.5*X+random.normal(0,1,n)))) # add noise to the truth
Y=(Y_noise>0.5).astype(float) # transform to binary data

# Plot true model and noisy data
plot(X,Y_true,'r.')
plot(X,Y_noise,'g.')
plot(X,Y,'b.')
xlabel('X')
ylabel('Y')
# Out:
# Text(0,0.5,'Y')

# %% [markdown]
# We build our neural net using a sigmoid activation function, corresponding to the logistic function. For such a classification problem, we try to minimize a loss function based on the binary cross-entropy.

# %%
# Build our model
model_classif1 = Sequential()

# Declare the layers
layers = [Dense(units=1, input_dim=1), Activation('sigmoid')]
 
# Add the layers to the model
for layer in layers:
    model_classif1.add(layer)
    
# Configure an optimizer used to minimize the loss function
sgd = SGD(lr=0.1, decay=.01)

# Compile our model
model_classif1.compile(loss='binary_crossentropy', optimizer=sgd)
 
# Fit the model
model_classif1.fit(X, Y, validation_split=0.2, epochs=100)

# Model weights
model_classif1.get_weights()
# Out:
# Train on 800 samples, validate on 200 samples
# Epoch 1/100
# 800/800 [==============================] - 0s 312us/step - loss: 0.7253 - val_loss: 0.3044
# Epoch 2/100
# 800/800 [==============================] - 0s 74us/step - loss: 0.2809 - val_loss: 0.2775
# Epoch 3/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.2582 - val_loss: 0.2608
# Epoch 4/100
# 800/800 [==============================] - 0s 88us/step - loss: 0.2436 - val_loss: 0.2498
# Epoch 5/100
# 800/800 [==============================] - 0s 90us/step - loss: 0.2338 - val_loss: 0.2418
# Epoch 6/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.2257 - val_loss: 0.2360
# Epoch 7/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.2200 - val_loss: 0.2310
# Epoch 8/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.2153 - val_loss: 0.2270
# Epoch 9/100
# 800/800 [==============================] - 0s 88us/step - loss: 0.2115 - val_loss: 0.2237
# Epoch 10/100
# 800/800 [==============================] - 0s 93us/step - loss: 0.2084 - val_loss: 0.2209
# Epoch 11/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.2055 - val_loss: 0.2186
# Epoch 12/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.2031 - val_loss: 0.2165
# Epoch 13/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.2014 - val_loss: 0.2148
# Epoch 14/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1992 - val_loss: 0.2132
# Epoch 15/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1976 - val_loss: 0.2117
# Epoch 16/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1960 - val_loss: 0.2105
# Epoch 17/100
# 800/800 [==============================] - 0s 88us/step - loss: 0.1949 - val_loss: 0.2093
# Epoch 18/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1935 - val_loss: 0.2083
# Epoch 19/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1924 - val_loss: 0.2073
# Epoch 20/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.1914 - val_loss: 0.2064
# Epoch 21/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1905 - val_loss: 0.2056
# Epoch 22/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1896 - val_loss: 0.2048
# Epoch 23/100
# 800/800 [==============================] - 0s 90us/step - loss: 0.1888 - val_loss: 0.2041
# Epoch 24/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1880 - val_loss: 0.2035
# Epoch 25/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1874 - val_loss: 0.2029
# Epoch 26/100
# 800/800 [==============================] - 0s 88us/step - loss: 0.1867 - val_loss: 0.2023
# Epoch 27/100
# 800/800 [==============================] - 0s 89us/step - loss: 0.1861 - val_loss: 0.2018
# Epoch 28/100
# 800/800 [==============================] - 0s 88us/step - loss: 0.1856 - val_loss: 0.2013
# Epoch 29/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.1850 - val_loss: 0.2008
# Epoch 30/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1844 - val_loss: 0.2003
# Epoch 31/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.1839 - val_loss: 0.1999
# Epoch 32/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.1836 - val_loss: 0.1995
# Epoch 33/100
# 800/800 [==============================] - 0s 89us/step - loss: 0.1831 - val_loss: 0.1991
# Epoch 34/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1826 - val_loss: 0.1987
# Epoch 35/100
# 800/800 [==============================] - 0s 89us/step - loss: 0.1822 - val_loss: 0.1984
# Epoch 36/100
# 800/800 [==============================] - 0s 90us/step - loss: 0.1818 - val_loss: 0.1980
# Epoch 37/100
# 800/800 [==============================] - 0s 83us/step - loss: 0.1815 - val_loss: 0.1977
# Epoch 38/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.1811 - val_loss: 0.1974
# Epoch 39/100
# 800/800 [==============================] - 0s 89us/step - loss: 0.1809 - val_loss: 0.1971
# Epoch 40/100
# 800/800 [==============================] - 0s 88us/step - loss: 0.1805 - val_loss: 0.1968
# Epoch 41/100
# 800/800 [==============================] - 0s 91us/step - loss: 0.1801 - val_loss: 0.1965
# Epoch 42/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1798 - val_loss: 0.1963
# Epoch 43/100
# 800/800 [==============================] - 0s 83us/step - loss: 0.1796 - val_loss: 0.1960
# Epoch 44/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1793 - val_loss: 0.1958
# Epoch 45/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1790 - val_loss: 0.1955
# Epoch 46/100
# 800/800 [==============================] - 0s 89us/step - loss: 0.1787 - val_loss: 0.1953
# Epoch 47/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.1785 - val_loss: 0.1951
# Epoch 48/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1783 - val_loss: 0.1949
# Epoch 49/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.1780 - val_loss: 0.1947
# Epoch 50/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1778 - val_loss: 0.1945
# Epoch 51/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1776 - val_loss: 0.1943
# Epoch 52/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1774 - val_loss: 0.1941
# Epoch 53/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1772 - val_loss: 0.1939
# Epoch 54/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.1769 - val_loss: 0.1937
# Epoch 55/100
# 800/800 [==============================] - 0s 90us/step - loss: 0.1768 - val_loss: 0.1936
# Epoch 56/100
# 800/800 [==============================] - 0s 88us/step - loss: 0.1766 - val_loss: 0.1934
# Epoch 57/100
# 800/800 [==============================] - 0s 90us/step - loss: 0.1764 - val_loss: 0.1932
# Epoch 58/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1762 - val_loss: 0.1931
# Epoch 59/100
# 800/800 [==============================] - 0s 89us/step - loss: 0.1760 - val_loss: 0.1929
# Epoch 60/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.1759 - val_loss: 0.1928
# Epoch 61/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.1757 - val_loss: 0.1926
# Epoch 62/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1756 - val_loss: 0.1925
# Epoch 63/100
# 800/800 [==============================] - 0s 91us/step - loss: 0.1754 - val_loss: 0.1924
# Epoch 64/100
# 800/800 [==============================] - 0s 83us/step - loss: 0.1752 - val_loss: 0.1922
# Epoch 65/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1751 - val_loss: 0.1921
# Epoch 66/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.1749 - val_loss: 0.1920
# Epoch 67/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1748 - val_loss: 0.1918
# Epoch 68/100
# 800/800 [==============================] - 0s 88us/step - loss: 0.1747 - val_loss: 0.1917
# Epoch 69/100
# 800/800 [==============================] - 0s 83us/step - loss: 0.1745 - val_loss: 0.1916
# Epoch 70/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.1744 - val_loss: 0.1915
# Epoch 71/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.1742 - val_loss: 0.1914
# Epoch 72/100
# 800/800 [==============================] - 0s 89us/step - loss: 0.1741 - val_loss: 0.1913
# Epoch 73/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1740 - val_loss: 0.1912
# Epoch 74/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1739 - val_loss: 0.1911
# Epoch 75/100
# 800/800 [==============================] - 0s 83us/step - loss: 0.1738 - val_loss: 0.1909
# Epoch 76/100
# 800/800 [==============================] - 0s 81us/step - loss: 0.1736 - val_loss: 0.1908
# Epoch 77/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.1735 - val_loss: 0.1907
# Epoch 78/100
# 800/800 [==============================] - 0s 83us/step - loss: 0.1735 - val_loss: 0.1906
# Epoch 79/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.1733 - val_loss: 0.1905
# Epoch 80/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.1732 - val_loss: 0.1905
# Epoch 81/100
# 800/800 [==============================] - 0s 89us/step - loss: 0.1731 - val_loss: 0.1904
# Epoch 82/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1730 - val_loss: 0.1903
# Epoch 83/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.1729 - val_loss: 0.1902
# Epoch 84/100
# 800/800 [==============================] - 0s 91us/step - loss: 0.1728 - val_loss: 0.1901
# Epoch 85/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1727 - val_loss: 0.1900
# Epoch 86/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.1726 - val_loss: 0.1899
# Epoch 87/100
# 800/800 [==============================] - 0s 87us/step - loss: 0.1725 - val_loss: 0.1898
# Epoch 88/100
# 800/800 [==============================] - 0s 91us/step - loss: 0.1725 - val_loss: 0.1898
# Epoch 89/100
# 800/800 [==============================] - 0s 85us/step - loss: 0.1723 - val_loss: 0.1897
# Epoch 90/100
# 800/800 [==============================] - 0s 82us/step - loss: 0.1722 - val_loss: 0.1896
# Epoch 91/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.1722 - val_loss: 0.1895
# Epoch 92/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1721 - val_loss: 0.1894
# Epoch 93/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1720 - val_loss: 0.1894
# Epoch 94/100
# 800/800 [==============================] - 0s 88us/step - loss: 0.1719 - val_loss: 0.1893
# Epoch 95/100
# 800/800 [==============================] - 0s 89us/step - loss: 0.1718 - val_loss: 0.1892
# Epoch 96/100
# 800/800 [==============================] - 0s 88us/step - loss: 0.1717 - val_loss: 0.1892
# Epoch 97/100
# 800/800 [==============================] - 0s 86us/step - loss: 0.1717 - val_loss: 0.1891
# Epoch 98/100
# 800/800 [==============================] - 0s 84us/step - loss: 0.1716 - val_loss: 0.1890
# Epoch 99/100
# 800/800 [==============================] - 0s 83us/step - loss: 0.1715 - val_loss: 0.1889
# Epoch 100/100
# 800/800 [==============================] - 0s 88us/step - loss: 0.1714 - val_loss: 0.1889
# [array([[0.630364]], dtype=float32), array([2.0056784], dtype=float32)]

# %% [markdown]
# The estimated weights can be far from the true parameters ($0.5$ and $2$). To improve the estimation, we can increase the database (*n* in the above code) and the number of iterations to fit the model (*epochs* in the *fit* function). Then, we plot the true (red) and estimated (green) classification models.

# %%
# Make prediction using the model
Y_hat = model_classif1.predict(X)

# Plot noisy data, true model and prediction
plot(X,Y,'b.')

plot(X,Y_true,'r.')
plot(X,Y_hat,'g.')

# %% [markdown]
# Now, let us consider a more complicated classification model where we have 2 input variables ($X_0$, $X_1$) and a binary output variable $Y$. The link between the $X$ variables and $Y$ is nonlinear (moon shape).

# %%
# Import machine learning library
from sklearn.datasets import make_moons

# Generate data
n=1000
X_true,Y_true=make_moons(noise=0.00001,random_state=0,n_samples=n) # true model
X,Y=make_moons(noise=0.2,random_state=0,n_samples=n) # noisy data

# Plot true model and noisy data
scatter(X[:,0], X[:,1], c=Y)
scatter(X_true[:,0], X_true[:,1], c=Y_true)
xlabel('X_0')
ylabel('X_1')
# Out:
# Text(0,0.5,'X_1')

# %% [markdown]
# Try first to adjust a simple neural net with 1 hidden layer, 1 neurone and a logistic loss function. Then, test
# a more complex network with 3 hidden layers and relu (rectified linear unit) activations. For more information concerning the different activation functions, please see https://fr.wikipedia.org/wiki/Fonction_d'activation#cite_note-7. We stock the fitted model in the variable *history*.

# %%
# Build our model
model_classif2 = Sequential()
 
# Declare the layers
#layers = [Dense(units=1, input_dim=2), Activation('sigmoid')] # try this one first
layers = [Dense(units=4, input_dim=2), Activation('relu'), # then this one
          Dense(units=4, input_dim=4), Activation('relu'),
          Dense(units=1, input_dim=4), Activation('sigmoid')]

# Add the layers to the model
for layer in layers:
    model_classif2.add(layer)
    
# Configure an optimizer used to minimize the loss function
sgd = SGD(lr=0.1, decay=.01) # try this one first
adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

# Compile our model
model_classif2.compile(loss='binary_crossentropy', optimizer=adam) # sgd or adam
 
# Fit the model
history = model_classif2.fit(X, Y, validation_split=0.2, epochs=1000, verbose=0)

# Model weights
model_classif2.get_weights()
# Out:
# [array([[ 0.7188419 , -0.8036042 , -2.1335053 ,  1.3265054 ],
#         [ 1.0210582 , -0.07630794,  0.7571326 , -0.09963065]],
#        dtype=float32),
#  array([-0.19871005,  0.8656183 , -0.35514268, -0.97709846], dtype=float32),
#  array([[-1.6167024 , -1.0169059 , -0.14527975, -1.2322485 ],
#         [ 0.725654  ,  1.7176722 , -0.0779113 ,  1.0463545 ],
#         [-1.9072971 , -3.2150178 ,  0.19400862, -1.7415016 ],
#         [ 0.87630945, -0.7116255 ,  2.2201843 ,  2.1267633 ]],
#        dtype=float32),
#  array([ 0.9355422 ,  0.64729387, -0.44031766,  0.20991609], dtype=float32),
#  array([[3.7331328],
#         [2.6705089],
#         [2.9004114],
#         [1.8836073]], dtype=float32),
#  array([-5.6090617], dtype=float32)]

# %%
# Make prediction using the model
Y_hat = model_classif2.predict(X)

# Plot noisy data, true model and prediction
subplot(2,2,1)
scatter(X[:,0], X[:,1], c=Y)
scatter(X_true[:,0], X_true[:,1], c=Y_true)
title('Noisy data and true model')
subplot(2,2,2)
scatter(X[:,0], X[:,1], c=Y_hat[:,0])
scatter(X_true[:,0], X_true[:,1], c=Y_true)
title('Noisy data and predictions')
# Out:
# Text(0.5,1,'Noisy data and predictions')

# %% [markdown]
# The predicted values (right) are given between $0$ (blue) and $1$ (red). The algorithm converges when the classification boundary is well defined between the 2 scatter plots. Finally, we can use the *history* variable and plot the evolution of the loss function for the training and test datasets.

# %%
# Summarize history for loss
plot(history.history['loss'])
plot(history.history['val_loss'])
ylabel('loss')
xlabel('epoch')
legend(['train', 'test'])

# %% [markdown]
# **Classification problem on real data**
#
# Congratulations, you are now ready to apply regression or classification problems on real data. Here, we propose to use a well known dataset in statistic: *iris*. The output variable $y$ are different iris species (Setosa, Versicolour, Virginica) and input variables $x$ are the length/width of the sepal/petal. Try to construct your own neural net, learn it on a training dataset ($x_{train}$ and $x_{train}$, 80%) and test it on a independant test dataset ($x_{test}$ and $y_{test}$, 20%).

# %%
from sklearn import datasets
# Load data
iris = datasets.load_iris()
X = iris.data
Y = iris.target
